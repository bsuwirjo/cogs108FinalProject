# %% [markdown]
# # Cogs 108 Final Project
#
# Bernard Suwirjo
#
# Ben Hazarian
#
# Cesar Reyes
#
# Eric Jiang
#
# Gauthier Pred'Astor Gris

# %%
# Necessary Imports
import numpy as np
import pandas as pd

# %%
# Load Datasets

# Baseball Dataset
#NFL_frame = pd.read_csv('data/NFL_16_17.csv')
NFL_frame = pd.read_csv('data/nfl_16.csv')
NFL_frame.head()
# Out:
#    Week  Day          Date    Time          Winner/tie Unnamed: 5  \
# 0     1  Thu   September 8  8:40PM      Denver Broncos        NaN
# 1     1  Sun  September 11  1:04PM   Green Bay Packers          @
# 2     1  Sun  September 11  1:04PM    Baltimore Ravens        NaN
# 3     1  Sun  September 11  1:05PM      Houston Texans        NaN
# 4     1  Sun  September 11  1:05PM  Kansas City Chiefs        NaN
#
#               Loser/tie Unnamed: 7  Pts  Pts.1  YdsW  TOW  YdsL  TOL
# 0     Carolina Panthers   boxscore   21     20   307    3   333    1
# 1  Jacksonville Jaguars   boxscore   27     23   294    0   348    1
# 2         Buffalo Bills   boxscore   13      7   308    1   160    0
# 3         Chicago Bears   boxscore   23     14   344    1   258    1
# 4    San Diego Chargers   boxscore   33     27   413    1   388    0

# %% [markdown]
# Data cleaning

# %%
NFL_frame = NFL_frame.drop(columns=['Day','Time','Date', 'Unnamed: 7'])
NFL_frame.rename(columns={'Unnamed: 5':'Home_play'}, inplace=True)

# %% [markdown]
# Putting 1 if winning team played at home and 0 otherwise

# %%
for index, row in NFL_frame.iterrows():
    if row['Home_play'] =='@':
        NFL_frame.set_value(index, 'Home_play', 0)
    else:
        NFL_frame.set_value(index, 'Home_play', 1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   """
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
NFL_frame.head()
NFL_frame = NFL_frame.loc[NFL_frame['Pts']!=NFL_frame['Pts.1']]

# %%
df_home = NFL_frame.loc[NFL_frame['Home_play']==1]
df_away = NFL_frame.loc[NFL_frame['Home_play']==0]

df_away.groupby('Winner/tie')['Home_play'].count()
# Out:
# Winner/tie
# Arizona Cardinals       3
# Atlanta Falcons         6
# Baltimore Ravens        2
# Buffalo Bills           3
# Carolina Panthers       2
# Cincinnati Bengals      2
# Dallas Cowboys          6
# Denver Broncos          4
# Detroit Lions           3
# Green Bay Packers       4
# Houston Texans          2
# Indianapolis Colts      4
# Jacksonville Jaguars    1
# Kansas City Chiefs      6
# Los Angeles Rams        3
# Miami Dolphins          4
# Minnesota Vikings       3
# New England Patriots    8
# New Orleans Saints      3
# New York Giants         4
# New York Jets           3
# Oakland Raiders         6
# Philadelphia Eagles     1
# Pittsburgh Steelers     5
# San Diego Chargers      2
# San Francisco 49ers     1
# Seattle Seahawks        3
# Tampa Bay Buccaneers    5
# Tennessee Titans        4
# Washington Redskins     4
# Name: Home_play, dtype: int64

# %% [markdown]
# Nb games

# %%
won_home = NFL_frame.groupby(['Winner/tie', 'Home_play'])['Home_play'].sum()

# %% [markdown]
# How many games won and lost

# %%
won_away = NFL_frame.groupby('Winner/tie')['Home_play'].sum()
won_home = NFL_frame.groupby('Winner/tie')['Home_play'].count() - won_away

won_away.head()
#lost = NFL_frame.groupby('Loser/tie')['Home_play']
#won_home = NFL_frame.groupby('Winner/tie')['Home_play'].sum()
#won_outside = 
#won_not_home = NFL_frame.groupby('Winner/tie')['Home_play'].sum()
#lost_home = NFL_frame.groupby('Loser/tie')['Winner/tie'].count()
# Out:
# Winner/tie
# Arizona Cardinals     6
# Atlanta Falcons      12
# Baltimore Ravens      6
# Buffalo Bills         6
# Carolina Panthers     7
# Name: Home_play, dtype: int64

# %%
NFL_frame.groupby(['Winner/tie', 'Home_play']).count()
# Out:
#                                 Week  Loser/tie  Pts  Pts.1  YdsW  TOW  YdsL  \
# Winner/tie           Home_play
# Arizona Cardinals    0             9          9    9      9     9    9     9
#                      1             6          6    6      6     6    6     6
# Atlanta Falcons      0            12         12   12     12    12   12    12
#                      1            12         12   12     12    12   12    12
# Baltimore Ravens     0            11         11   11     11    11   11    11
#                      1             6          6    6      6     6    6     6
# Buffalo Bills        0            10         10   10     10    10   10    10
#                      1             6          6    6      6     6    6     6
# Carolina Panthers    0            10         10   10     10    10   10    10
#                      1             7          7    7      7     7    7     7
# Chicago Bears        0             6          6    6      6     6    6     6
#                      1             2          2    2      2     2    2     2
# Cincinnati Bengals   0             8          8    8      8     8    8     8
#                      1             5          5    5      5     5    5     5
# Cleveland Browns     0             1          1    1      1     1    1     1
# Dallas Cowboys       0            10         10   10     10    10   10    10
#                      1            12         12   12     12    12   12    12
# Denver Broncos       0             9          9    9      9     9    9     9
#                      1             5          5    5      5     5    5     5
# Detroit Lions        0            10         10   10     10    10   10    10
#                      1             8          8    8      8     8    8     8
# Green Bay Packers    0            11         11   11     11    11   11    11
#                      1             8          8    8      8     8    8     8
# Houston Texans       0            11         11   11     11    11   11    11
#                      1             3          3    3      3     3    3     3
# Indianapolis Colts   0             7          7    7      7     7    7     7
#                      1             5          5    5      5     5    5     5
# Jacksonville Jaguars 0             9          9    9      9     9    9     9
#                      1             6          6    6      6     6    6     6
# Kansas City Chiefs   0            12         12   12     12    12   12    12
# ...                              ...        ...  ...    ...   ...  ...   ...
# Miami Dolphins       0            10         10   10     10    10   10    10
#                      1             6          6    6      6     6    6     6
# Minnesota Vikings    0            13         13   13     13    13   13    13
#                      1             9          9    9      9     9    9     9
# New England Patriots 0            17         17   17     17    17   17    17
#                      1            15         15   15     15    15   15    15
